# %% [markdown]
# <a href="https://colab.research.google.com/github/carloscelestino1/DataScience-and-ML/blob/main/Atividade02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#Dados obtidos por requisição de url disponível no site http://dados.recife.pe.gov.br/tl/dataset/relacao-de-pessoas-vacinadas-covid-19/resource/966e9c4c-df45-40d7-9c58-2f13c61a6d28 

df = pd.read_csv('http://dados.recife.pe.gov.br/dataset/f381d9ea-4839-44a6-b4fe-788239189900/resource/966e9c4c-df45-40d7-9c58-2f13c61a6d28/download/vacinados.csv', sep=";")

# %%
df
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
values = ['MASCULINO']
masc = df[df.sexo.isin(values)]
qtdHomens = len(masc)

# %%
values = ['FEMININO']
fem = df[df.sexo.isin(values)]
qtdMulher = len(fem)

# %%
x = ['homem','mulher']
y = [qtdHomens,qtdMulher]
fig, ax = plt.subplots()
for i, v in enumerate(y):
    ax.text(i-.25, v/y[i], y[i], fontsize=20, color="black")

plt.title("Relação homem x mulher")
ax.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
freq = df.value_counts('data_vacinacao') 
print(freq)
# Out:
# data_vacinacao
# 2021-09-02    15380
# 2021-09-03    15214
# 2021-09-15    15039
# 2021-09-09    14902
# 2021-09-01    14900
#               ...
# 2021-02-06     1245
# 2021-01-31     1042
# 2021-01-23      893
# 2021-01-24      656
# 2021-02-07      387
# Length: 397, dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
copia = df.copy()

# %%
excluirColuna = df.drop(columns = ['local_vacinacao'])

# %%
excluirColuna
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
organizar = df.sort_values(by = 'dose')
organizar
# Out:
#                     cpf                                     nome       sexo  \
# 1703648  ***.103.504-**                JOYCINEIDE DA SILVA NUNES   FEMININO
# 1823451  ***.923.557-**                       LAVINE FERRAZ MOTA   FEMININO
# 1823449  ***.101.334-**                   LAVINE DA SILVA GUEDES   FEMININO
# 1823447  ***.550.944-**       LAVINEA VITORIA BATISTA DOS SANTOS   FEMININO
# 1823446  ***.737.414-**        LAVINEA MARIA MARQUES DE OLIVEIRA   FEMININO
# ...                 ...                                      ...        ...
# 1095982  ***.399.494-**                GABRIEL GUIMARAES FURTADO  MASCULINO
# 1571429  ***.869.084-**  JOSÉ DAVID ERINALDO DA SILVA NASCIMENTO  MASCULINO
# 2618446  ***.789.364-**                  NERILZA PEDROSA DE LIMA   FEMININO
# 2357044  ***.169.924-**          MARIA LETICIA DA ROCHA CARVALHO   FEMININO
# 3407297             NaN                                      NaN        NaN
#
#                                         grupo  \
# ...

# %%
df.rename(columns = {'dose':'num_dose'}, inplace=True)
df
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
df.isnull()
# Out:
#            cpf   nome   sexo  grupo  vacina   lote  num_dose  data_vacinacao  \
# 0        False  False  False  False   False  False     False           False
# 1        False  False  False  False   False  False     False           False
# 2        False  False  False  False   False  False     False           False
# 3        False  False  False  False   False  False     False           False
# 4        False  False  False  False   False  False     False           False
# ...        ...    ...    ...    ...     ...    ...       ...             ...
# 3407293  False  False  False  False   False  False     False           False
# 3407294  False  False  False  False   False  False     False           False
# 3407295  False  False  False  False   False  False     False           False
# 3407296  False  False  False  False   False  False     False           False
# 3407297   True   True   True   True    True   True      True            True
#
#          local_vacinacao
# ...

# %%
df.tail()
# Out:
#                     cpf                        nome       sexo   grupo  \
# 3407293  ***.619.454-**  NECIRA FERREIRA DE SANTANA   FEMININO  IDOSOS
# 3407294  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407295  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407296  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407297             NaN                         NaN        NaN     NaN
#
#                                      vacina     lote  num_dose data_vacinacao  \
# 3407293              3 - COMIRNATY (PFIZER)   FF8848       3.0     2021-09-29
# 3407294  1 - CORONAVAC - SINOVAC (BUTANTAN)  210052A       2.0     2021-03-11
# 3407295              3 - COMIRNATY (PFIZER)   FF8848       3.0     2021-09-29
# 3407296  1 - CORONAVAC - SINOVAC (BUTANTAN)   210016       1.0     2021-02-17
# 3407297                                 NaN      NaN       NaN            NaN
#
#                                 local_vacinacao
# ...

# %%
df.head()
# Out:
#               cpf                           nome       sexo  \
# 0  ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1  ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
#
#                                    grupo  \
# 0  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 2                 TRABALHADORES DA SAÚDE
# 3                 TRABALHADORES DA SAÚDE
# 4                 TRABALHADORES DA SAÚDE
#
#                                               vacina         lote  num_dose  \
# 0  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)  219VCD270W        2.0
# 1  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)   216VCD206Z       1.0
# 2                 1 - CORONAVAC - SINOVAC (BUTANTAN)       210043       2.0
# ...

# %%
df.shape
# Out:
# (3407298, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3407298 entries, 0 to 3407297
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   cpf              object
#  1   nome             object
#  2   sexo             object
#  3   grupo            object
#  4   vacina           object
#  5   lote             object
#  6   num_dose         float64
#  7   data_vacinacao   object
#  8   local_vacinacao  object
# dtypes: float64(1), object(8)
# memory usage: 234.0+ MB
